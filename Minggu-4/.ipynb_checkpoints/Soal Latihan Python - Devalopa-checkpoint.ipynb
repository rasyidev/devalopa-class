# %% [markdown]
# ## Latihan Soal
#
# **NAMA   :**
#
# **PRODI  :**
#
# _Deadline: Sabtu, 12 Maret 2022. 23.59 WIB_
#
# **Tidak diperbolehkan menggunakan built-in function**

# %% [markdown]
# #### 1. Buatlah program yang dapat mengalikan semua elemen di dalam list berikut!
# ```python
# angka = [3,5,1,6,9,3,8,2,9]
# ```
#
# #### 2. Buatlah program yang dapat mengalikan semua elemen di dalam list dua dimensi berikut!
# ```python
# matriks = [[1,4,2],[2,4],[1,5,8,4,2]]
#
# ```
#
# #### 3. Mirip dengan soal nomor 3, buatlah program yang dapat mengalikan setiap elemen, tetapi hanya angka yang ganjil saja!
# ```python
# matriks = [[1,4,2],[2,4],[1,5,8,4,2]]
#
# ```
#
# #### 4. Buatlah fungsi dari soal nomor 1-4!
#
# #### 5. Implementasikan diagram berikut ke dalam class python!

# %% [markdown]
# ![image_2022-03-08_130352.png](attachment:image_2022-03-08_130352.png)

# %% [markdown]
# - fungsi `cetak_info()` mencetak informasi atribut yang ada di dalam kelas
# - Kelas Gadget tidak boleh diinisiasi, yang boleh hanyalah kelas turunannya
# - fungsi `charge_baterai()`
#
#     Smartphone: + 100 mAh
#
#     Smartwatch: + 50 mAh
#
#     Laptop    : + 150 mAh
